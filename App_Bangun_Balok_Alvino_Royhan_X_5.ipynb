# %% [markdown]
# <a href="https://colab.research.google.com/github/alvinoroyhan25/KKA-X-Semester-1/blob/main/App_Bangun_Balok_Alvino_Royhan_X_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama kelompok : ayam terbang
# Nama : Alvino Royhan
# Kelas : X-5
# No. absen : 8

# %%
panjang = float(input("Masukkan panjang Balok (cm) : "))
lebar = float(input(" Masukkan lebar balok (cm) : "))
tinggi = float(input(" Masukkan tinggi balok (cm) : "))

volume = panjang * lebar * tinggi

print(f"Luas persegi panjang adalah: {volume} cm^2.")
# Out:
# Masukkan panjang Balok (cm) : 5
#  Masukkan lebar balok (cm) : 3
#  Masukkan tinggi balok (cm) : 3
# Luas persegi panjang adalah: 45.0 cm^2.
