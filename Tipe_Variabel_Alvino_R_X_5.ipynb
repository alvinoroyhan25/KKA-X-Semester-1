# %% [markdown]
# <a href="https://colab.research.google.com/github/alvinoroyhan25/KKA-X-Semester-1/blob/main/Tipe_Variabel_Alvino_R_X_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama:Alvino Royhan
#
# Kelas:X.5
#
# No.absen:8

# %% [markdown]
# #Konsep Dasar Variabel

# %%
print("alvino@gmail.com")
print("alvino@gmail.com")
print("alvino@gmail.com")
# Out:
# alvino@gmail.com
# alvino@gmail.com
# alvino@gmail.com

# %%
email_user_1 = "alvino@gmail.com"

print(email_user_1)
print(email_user_1)
print(email_user_1)
# Out:
# alvino@gmail.com
# alvino@gmail.com
# alvino@gmail.com

# %% [markdown]
# #Peraturan Penulisan Variabel

# %%
email user 2 = "orang@gmail.com"

print(email user 2)
# Out:
#   File "/tmp/ipython-input-3572280649.py", line 1
#     email user 2 = "orang@gmail.com"
#           ^
# SyntaxError: invalid syntax

# %%
#Hanya boleh menggunakan angka, huruf dan underscore

emailuser2 = "orang@gmail.com"

print(emailuser2)
# Out:
# orang@gmail.com

# %%
email_user_2
